# %%
import pandas as pd

sensitive_data = pd.read_csv("sensitive_data1.csv", sep=',', error_bad_lines=False, encoding="utf8")

# %%
display(sensitive_data)
# Out:
#                                                  text  type      source  \
# 0   中国政府觉得有必要改变已经被严重操纵并利于亲北京阵营的选举制度，这有点不可思议。香港的立法会...  news         BBC
# 1   高智晟一个已多年不交党费，不过“组织生活”的党员，从即日起宣布：退出这个无仁、无义、无人性的...  news         CDS
# 2   网络评论员（即网评员或五毛党）是中国大陆特有的一种称呼，指受中国大陆的行政机关、高校、网站雇...  wiki         CDS
# 3   加速主义（Accelerationism）原指一种政治与社会理论，认为资本主义制度或历史上某...  blog         CDS
# 4   因此，加速主义也陷入一种道德困境并引起争议，在端传媒《加速主义：作为一种严肃的政治（抗争）立...  blog         CDS
# ..                                                ...   ...         ...
# 95  前六四学生领袖王丹举行线上六四31周年纪念会。他说，这场抗争进入网络化，上一代学运人士和新世...  news  voachinese
# 96  六月四号，晚间八点，三千位台、港人齐聚在台湾自由广场。“光复香港！时代革命！” 这是他们企盼...  news  voachinese
# 97  在中国军队开枪镇压和平示威学生和民众的天安门事件31周年纪念日当天，六四事件遇难者群体“天安...  news  voachinese
# 98  6月4日上午， “天安门母亲”发言人尤维洁主持了这次在疫情尚未结束之时举行的集体祭奠活动。六...  news  voachinese
# 99  六四事件31周年纪念日当天下午，美国之音记者前往天安门、南池子、木樨地、王府井等当年曾发生伤...  news  voachinese
#
#                                title    category      label
# ...

# %%
non_sensitive_data = pd.read_csv("non_sensitive_data.csv", sep=',', error_bad_lines=False, encoding="utf8")
display(non_sensitive_data)
# Out:
#                              text      category                   id  \
# 0                京城最值得你来场文化之旅的博物馆  news_culture  6551700932705387022
# 1               发酵床的垫料种类有哪些？哪种更好？  news_culture  6552368441838272771
# 2           上联：黄山黄河黄皮肤黄土高原。怎么对下联？  news_culture  6552407965343678723
# 3       林徽因什么理由拒绝了徐志摩而选择梁思成为终身伴侣？  news_culture  6552332417753940238
# 4                        黄杨木是什么树？  news_culture  6552475601595269390
# ...                           ...           ...                  ...
# 1236                美国究竟发达到什么程度了？    news_world  6552316767996215560
# 1237      如果美国各个州独立了，世界格局会发生什么变化？    news_world  6552445612715933959
# 1238        美国建国不过两百年，为什么会成为世界强国？    news_world  6552419386114703619
# 1239        纠结七天的日本行程，关西进出该不该去东京？    news_world  6552491187465355523
# 1240  印度能够复制中国奇迹，超过日本成为世界第三大经济体吗？    news_world  6552218782532632840
#
#               label
# 0     non-sensitive
# 1     non-sensitive
# 2     non-sensitive
# 3     non-sensitive
# 4     non-sensitive
# ...
